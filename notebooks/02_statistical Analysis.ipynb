# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import missingno as msno
from ipywidgets import interact, Dropdown

# %%
current_dir = Path.cwd()
work_dir = current_dir.parent.parent
data_dir = f'{work_dir}/data'

# %%
df = pd.read_csv(f"{data_dir}/selected_df.csv")
df.head()
# Out:
#      Age     LnAge       Age2           Age3     Sex  \
# 0  62.50  4.135167  3906.2500  244140.625000  Female
# 1   6.75  1.909543    45.5625     307.546875  Female
# 2  52.50  3.960813  2756.2500  144703.125000    Male
# 3  21.25  3.056357   451.5625    9595.703125    Male
# 4  64.75  4.170534  4192.5625  271468.421875    Male
#
#                                  Race  Height  LnHeight   Height2  Weight  \
# 0  Other race, including multi-racial   154.7  5.041488  23932.09   138.9
# 1  Other race, including multi-racial   120.4  4.790820  14496.16    22.0
# 2                    Mexican American   154.4  5.039547  23839.36    65.7
# 3                               Black   182.7  5.207845  33379.29    77.9
# 4                    Mexican American   173.8  5.157905  30206.44   101.6
#
#      BMI  Height2_x_Race  Age_Height   Age_Height2  Baseline_FEV1_L  \
# 0  58.04        95728.36    9668.750  1.495756e+06            2.025
# 1  15.18        57984.64     812.700  9.784908e+04            1.551
# 2  27.56        47678.72    8106.000  1.251566e+06            2.957
# 3  23.34        33379.29    3882.375  7.093099e+05            4.541
# 4  33.64        60412.88   11253.550  1.955867e+06            2.920
#
#    Baseline_FVC_L  Baseline_FEV1_FVC_Ratio
# 0           2.473                 0.818844
# 1           1.742                 0.890356
# 2           3.545                 0.834133
# 3           4.928                 0.921469
# 4           3.907                 0.747377
